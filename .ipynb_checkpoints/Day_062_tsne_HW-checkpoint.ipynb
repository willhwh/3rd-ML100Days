# %% [markdown]
# # t-sne 觀察 : 流形還原

# %% [markdown]
# # [作業目標]
# - 試著模仿範例寫法, 觀察 S 形使用 t-SNE , 在不同困惑度 (perplexity) 下的流形還原效果

# %% [markdown]
# # [作業重點]
# - 使用 S 形資料集, 觀察 t-sne 在困惑度 (perplexity) 有所不同時, 流形還原的效果如何變化 (In[4], Out[4])
# - Hint : ax.scatter(Y[red, 0], Y[red, 1], c="r") 與 ax.scatter(Y[green, 0], Y[green, 1], c="g") 兩行改一行 ax.scatter(Y[:, 0], Y[:, 1], c=color)

# %%
# 載入套件
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets
from time import time

# %%
# 設定模型與繪圖參數
n_samples = 300
n_components = 2
perplexities = [4, 6, 9, 14, 21, 30, 45, 66, 100]


# 設定S曲線資料點
X, color = datasets.samples_generator.make_s_curve(n_samples, random_state=0)#datasets.make_s_curve
#X, y = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)

# %%
(fig, subplots) = plt.subplots(2, 5, figsize=(15, 6))

# 繪製資料原圖
ax = subplots[0][0]
ax.set_title("Original")
ax.scatter(X[:, 0], X[:, 2], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')


# 繪製不同 perplexity 下的 t-SNE 流形還原圖 (請注意! 語法也要對應調整)
for i, perplexity in enumerate(perplexities):
    if i<4:
        ax = subplots[0][i+1]
    else:
        ax = subplots[1][i-4]

    t0 = time()
    tsne = manifold.TSNE(n_components=n_components, init='random',
                         random_state=0, perplexity=perplexity)
    Y = tsne.fit_transform(X)
    t1 = time()
    print("s_curve, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=color)
    # c=color >>>colorful
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
    
plt.show()
# Out:
# s_curve, perplexity=4 in 1.1 sec
# s_curve, perplexity=6 in 1.1 sec
# s_curve, perplexity=9 in 1.2 sec
# s_curve, perplexity=14 in 1.2 sec
# s_curve, perplexity=21 in 1.7 sec
# s_curve, perplexity=30 in 1.8 sec
# s_curve, perplexity=45 in 2.3 sec
# s_curve, perplexity=66 in 1.6 sec
# s_curve, perplexity=100 in 2.3 sec

# %%
Y[1,1],Y[1,0],Y[0,1]
# Out:
# (-2.488999, -3.9582782, -2.3454792)

# %%
Y[:5]
# Out:
# array([[-0.83639455, -2.3454792 ],
#        [-3.9582782 , -2.488999  ],
#        [-2.0341396 , -0.6273779 ],
#        [-0.8965121 ,  0.2732357 ],
#        [ 1.668089  , -0.16472536]], dtype=float32)

# %%
color[:5]
# Out:
# array([ 0.46005644,  2.028112  ,  0.968522  ,  0.42301403, -0.71953656])

# %% [markdown]
# # 作業
# * 將原始資料集換為S型圖, 觀察不同 perplexity 下的流形還原結果

# %% [markdown]
# > perplexity 越低時, 圖形越零散, 越高時不僅分群好, 也讓圖形更接近原圖
#  但 perplexity 越高, 執行時間也越久

# %%
X, y = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)
red = y == 0 # 將 y 為 0 的 index set 存成變數 red
#return T or F
green = y == 1 # 將 y 為 1 的 index set 存成變數 green

# %%
X[:5]
# Out:
# array([[ 0.05035106, -1.07817658],
#        [ 0.44751006, -0.25674888],
#        [-0.58281536,  0.07358659],
#        [-0.13540474, -0.99467222],
#        [-0.12281785, -0.44932488]])

# %%
y[:5]
# Out:
# array([0, 1, 1, 0, 1])

# %%
red[:5]
# Out:
# array([ True, False, False,  True, False])

# %%
X[red, 0][:5]
# if True 
# return X[0]
# Out:
# array([ 0.05035106, -0.13540474, -0.37383259,  0.52778786, -0.04141849])
