# %% [markdown]
# # 作業
# * 選擇迴歸資料集(右) - 交錯六群，在其他參數保持預設值的情況下，只允許調整隱藏層層數與神經元數量，且遵守下列限制
# > * 隱藏層神經元總數最多 8 個 (即 : 可以單層 8 個，或兩層 5 個與 3 個)
# > * 遞迴次數只允許跑到500次
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的神經元參數與 Test Loss 數

# %% [markdown]
# # 1
# 0.013 test loss
#
# 2 hidden layers, 5 and 2 neurons respectively for two of them

# %% [markdown]
# ![Screen%20Shot%202020-12-23%20at%208.43.27%20PM.png](attachment:Screen%20Shot%202020-12-23%20at%208.43.27%20PM.png)

# %% [markdown]
# # 2
# 0.014 test loss
#
# 1 hidden layers and 8 neurons

# %% [markdown]
# ![Screen%20Shot%202020-12-23%20at%208.44.37%20PM.png](attachment:Screen%20Shot%202020-12-23%20at%208.44.37%20PM.png)
